# %%
import os
import sys
import numpy as np 
import torch

# %%
path='/path/to/result_direcotry'

# %%
for file in os.listdir(path):
    print(file)
    data = np.load(os.path.join(path, file)) 
    print(type(data))
    print(data.files)
    print(data['outputs']
    print()
# Out:
# video_test_0001159.npz
# <class 'numpy.lib.npyio.NpzFile'>
# ['avg_score', 'weight', 'global_score', 'branch_scores']
# (48, 21)
# [20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20
#  20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20]
# <class 'numpy.ndarray'>
#
# video_test_0000724.npz
# <class 'numpy.lib.npyio.NpzFile'>
# ['avg_score', 'weight', 'global_score', 'branch_scores']
# (48, 21)
# [20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20
#  20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20]
# <class 'numpy.ndarray'>
#
# video_test_0001483.npz
# <class 'numpy.lib.npyio.NpzFile'>
# ['avg_score', 'weight', 'global_score', 'branch_scores']
# (48, 21)
# [20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20
#  20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20 20]
# <class 'numpy.ndarray'>
#
# video_test_0000556.npz
# <class 'numpy.lib.npyio.NpzFile'>
# ...
